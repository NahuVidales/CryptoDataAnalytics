# %%
import pandas as pd
import json

# %%
# Ruta del archivo JSON
json_path = r'Dataset JSON/informacion general/arkham.json'

# Cargar el contenido del archivo JSON
with open(json_path, 'r') as file:
    json_data = json.load(file)

# Normalizar el JSON y crear un DataFrame
arkham = pd.json_normalize(json_data)


#eliminamos todas las columnas nulas o que sean iguales a 0
arkham = arkham.dropna(axis=1, how='all')
arkham = arkham.loc[:, (arkham != 0).any(axis=0)]

#Eliminamos todas las columnas que contengan la palabra "community", "market_data.ath", "description"
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='community')))]
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='market_data.ath')))]
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='description')))]

#Le cambiamos los nombres a las columnas que nos interesan "market_data.circulating_supply" y "market_data.circulating_supply"
arkham = arkham.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
arkham = arkham.rename(columns={'market_data.total_supply': 'total_supply'})
#Eliminamos las columnas que no nos interesan que contienen "market_data", "localization", "links", "image"
# ya que nos interesan
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='market_data')))]
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='localization')))]
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='links')))]
arkham = arkham[arkham.columns.drop(list(arkham.filter(regex='image')))]

arkham
# Out:
#        id symbol    name asset_platform_id  \
# 0  arkham   arkm  Arkham          ethereum
#
#                                 categories additional_notices country_origin  \
# 0  [Binance Launchpad, Ethereum Ecosystem]                 []
#
#                              contract_address  sentiment_votes_up_percentage  \
# 0  0x6e2a43be0b1d33b726f0ca3b8de60b3482b8b050                          88.89
#
#    sentiment_votes_down_percentage  ...  market_cap_rank  status_updates  \
# 0                            11.11  ...              358              []
#
#                last_updated  \
# 0  2023-08-10T20:09:53.032Z
#
#                                              tickers  \
# 0  [{'base': 'ARKM', 'target': 'USDT', 'market': ...
#
#                            platforms.ethereum  \
# 0  0x6e2a43be0b1d33b726f0ca3b8de60b3482b8b050
#
#   detail_platforms.ethereum.decimal_place  \
# 0                                      18
#
#    detail_platforms.ethereum.contract_address total_supply  \
# ...

# %%
# Ruta del archivo JSON
json_path_bitcoin = r'Dataset JSON/informacion general/bitcoin.json'

# Cargar el contenido del archivo JSON
with open(json_path_bitcoin, 'rb') as file:
    json_data_bitcoin = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_bitcoin = json.loads(json_data_bitcoin)

# Normalizar el JSON y crear un DataFrame
bitcoin = pd.json_normalize(json_dict_bitcoin)

# Eliminar columnas nulas o que sean iguales a 0
bitcoin = bitcoin.dropna(axis=1, how='all')
bitcoin = bitcoin.loc[:, (bitcoin != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='community')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='market_data.ath')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='description')))]

# Cambiar nombres de columnas
bitcoin = bitcoin.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
bitcoin = bitcoin.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='market_data')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='localization')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='links')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='image')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='developer_data')))]
bitcoin = bitcoin[bitcoin.columns.drop(list(bitcoin.filter(regex='public_interest')))]
bitcoin
# Out:
#         id symbol     name  block_time_in_minutes hashing_algorithm  \
# 0  bitcoin    btc  Bitcoin                     10           SHA-256
#
#                        categories additional_notices country_origin  \
# 0  [Cryptocurrency, Layer 1 (L1)]                 []
#
#   genesis_date  sentiment_votes_up_percentage  ...  coingecko_score  \
# 0   2009-01-03                          82.12  ...           83.151
#
#    developer_score  liquidity_score  status_updates              last_updated  \
# 0           99.241          100.011              []  2023-08-10T04:18:21.445Z
#
#                                              tickers  platforms.  \
# 0  [{'base': 'BTC', 'target': 'USDT', 'market': {...
#
#   detail_platforms..contract_address total_supply circulating_supply
# 0                                        21000000           19452943
#
# [1 rows x 24 columns]

# %%
# Ruta del archivo JSON
json_path_bnb = r'Dataset JSON/informacion general/bnb.json'

# Cargar el contenido del archivo JSON
with open(json_path_bnb, 'rb') as file:
    json_data_bnb = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_bnb = json.loads(json_data_bnb)

# Normalizar el JSON y crear un DataFrame
bnb = pd.json_normalize(json_dict_bnb)

# Eliminar columnas nulas o que sean iguales a 0
bnb = bnb.dropna(axis=1, how='all')
bnb = bnb.loc[:, (bnb != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='community')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='market_data.ath')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='description')))]

# Cambiar nombres de columnas
bnb = bnb.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
bnb = bnb.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='market_data')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='localization')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='links')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='image')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='developer_data')))]
bnb = bnb[bnb.columns.drop(list(bnb.filter(regex='public_interest')))]
bnb
# Out:
#             id symbol name                                         categories  \
# 0  binancecoin    bnb  BNB  [Alleged SEC Securities, Smart Contract Platfo...
#
#   additional_notices country_origin genesis_date  \
# 0                 []                  2017-07-08
#
#    sentiment_votes_up_percentage  sentiment_votes_down_percentage  \
# 0                          61.11                            38.89
#
#    watchlist_portfolio_users  ...  \
# 0                     641529  ...
#
#                                       status_updates  \
# 0  [{'description': 'Binance Black Friday - $100,...
#
#                last_updated  \
# 0  2023-08-10T04:16:16.616Z
#
#                                              tickers  platforms.  \
# 0  [{'base': 'BNB', 'target': 'USDT', 'market': {...
#
#                            platforms.ethereum  \
# 0  0xb8c77482e45f1f44de1745f52c74426c631bdd52
#
#   detail_platforms..contract_address detail_platforms.ethereum.decimal_place  \
# ...

# %%
# Ruta del archivo JSON
json_path_dogecoin = r'Dataset JSON/informacion general/dogecoin.json'

# Cargar el contenido del archivo JSON
with open(json_path_dogecoin, 'rb') as file:
    json_data_dogecoin = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_dogecoin = json.loads(json_data_dogecoin)

# Normalizar el JSON y crear un DataFrame
dogecoin = pd.json_normalize(json_dict_dogecoin)

# Eliminar columnas nulas o que sean iguales a 0
dogecoin = dogecoin.dropna(axis=1, how='all')
dogecoin = dogecoin.loc[:, (dogecoin != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='community')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='market_data.ath')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='description')))]

# Cambiar nombres de columnas
dogecoin = dogecoin.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
dogecoin = dogecoin.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='market_data')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='localization')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='links')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='image')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='developer_data')))]
dogecoin = dogecoin[dogecoin.columns.drop(list(dogecoin.filter(regex='public_interest')))]
dogecoin
# Out:
#          id symbol      name  block_time_in_minutes hashing_algorithm  \
# 0  dogecoin   doge  Dogecoin                      1            Scrypt
#
#                                     categories additional_notices  \
# 0  [Cryptocurrency, BNB Chain Ecosystem, Meme]                 []
#
#   country_origin genesis_date  sentiment_votes_up_percentage  ...  \
# 0                  2013-12-08                          67.57  ...
#
#    coingecko_score  developer_score  liquidity_score  status_updates  \
# 0           65.012           75.114           66.788              []
#
#                last_updated  \
# 0  2023-08-10T04:22:37.907Z
#
#                                              tickers  platforms.  \
# 0  [{'base': 'DOGE', 'target': 'USDT', 'market': ...
#
#   detail_platforms..contract_address  total_supply circulating_supply
# 0                                     1.405276e+11       1.405278e+11
#
# [1 rows x 24 columns]

# %%
# Ruta del archivo JSON
json_path_ethereum = r'Dataset JSON/informacion general/ethereum.json'

# Cargar el contenido del archivo JSON
with open(json_path_ethereum, 'rb') as file:
    json_data_ethereum = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_ethereum = json.loads(json_data_ethereum)

# Normalizar el JSON y crear un DataFrame
ethereum = pd.json_normalize(json_dict_ethereum)

# Eliminar columnas nulas o que sean iguales a 0
ethereum = ethereum.dropna(axis=1, how='all')
ethereum = ethereum.loc[:, (ethereum != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='community')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='market_data.ath')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='description')))]

# Cambiar nombres de columnas
ethereum = ethereum.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
ethereum = ethereum.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='market_data')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='localization')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='links')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='image')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='developer_data')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='public_interest')))]
ethereum = ethereum[ethereum.columns.drop(list(ethereum.filter(regex='ico_data')))]
ethereum
# Out:
#          id symbol      name hashing_algorithm  \
# 0  ethereum    eth  Ethereum            Ethash
#
#                                           categories additional_notices  \
# 0  [Smart Contract Platform, Layer 1 (L1), Ethere...                 []
#
#   country_origin genesis_date  sentiment_votes_up_percentage  \
# 0                  2015-07-30                          67.27
#
#    sentiment_votes_down_percentage  ...  coingecko_score  developer_score  \
# 0                            32.73  ...           78.783           97.494
#
#    liquidity_score  status_updates              last_updated  \
# 0           95.183              []  2023-08-10T04:18:44.864Z
#
#                                              tickers platforms.  \
# 0  [{'base': 'ETH', 'target': 'USDT', 'market': {...
#
#   detail_platforms..contract_address  total_supply circulating_supply
# 0                                     1.201525e+08       1.201525e+08
#
# [1 rows x 23 columns]

# %%
# Ruta del archivo JSON
json_path_matic = r'Dataset JSON/informacion general/matic.json'

# Cargar el contenido del archivo JSON
with open(json_path_matic, 'rb') as file:
    json_data_matic = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_matic = json.loads(json_data_matic)

# Normalizar el JSON y crear un DataFrame
matic = pd.json_normalize(json_dict_matic)

# Eliminar columnas nulas o que sean iguales a 0
matic = matic.dropna(axis=1, how='all')
matic = matic.loc[:, (matic != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
matic = matic[matic.columns.drop(list(matic.filter(regex='community')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='market_data.ath')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='description')))]

# Cambiar nombres de columnas
matic = matic.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
matic = matic.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
matic = matic[matic.columns.drop(list(matic.filter(regex='market_data')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='localization')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='links')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='image')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='developer_data')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='public_interest')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='ico_data')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='detail_platforms')))]
matic = matic[matic.columns.drop(list(matic.filter(regex='platforms')))]
matic
# Out:
#               id symbol     name asset_platform_id  \
# 0  matic-network  matic  Polygon          ethereum
#
#                                           categories additional_notices  \
# 0  [Binance Launchpad, Alleged SEC Securities, Ze...                 []
#
#   country_origin                            contract_address  \
# 0             IN  0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0
#
#    sentiment_votes_up_percentage  sentiment_votes_down_percentage  ...  \
# 0                          71.19                            28.81  ...
#
#    market_cap_rank  coingecko_rank  coingecko_score  developer_score  \
# 0               12              66            48.86           62.496
#
#    liquidity_score  status_updates              last_updated  \
# 0           68.532              []  2023-08-10T20:16:34.640Z
#
#                                              tickers total_supply  \
# 0  [{'base': 'MATIC', 'target': 'USDT', 'market':...  10000000000
#
#    circulating_supply
# ...

# %%
# Ruta del archivo JSON
json_path_pepe = r'Dataset JSON/informacion general/pepe.json'

# Cargar el contenido del archivo JSON
with open(json_path_pepe, 'rb') as file:
    json_data_pepe = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_pepe = json.loads(json_data_pepe)

# Normalizar el JSON y crear un DataFrame
pepe = pd.json_normalize(json_dict_pepe)

# Eliminar columnas nulas o que sean iguales a 0
pepe = pepe.dropna(axis=1, how='all')
pepe = pepe.loc[:, (pepe != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='community')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='market_data.ath')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='description')))]

# Cambiar nombres de columnas
pepe = pepe.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
pepe = pepe.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='market_data')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='localization')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='links')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='image')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='developer_data')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='public_interest')))]
pepe = pepe[pepe.columns.drop(list(pepe.filter(regex='ico_data')))]
pepe
# Out:
#      id symbol  name asset_platform_id  \
# 0  pepe   pepe  Pepe          ethereum
#
#                                           categories additional_notices  \
# 0  [Arbitrum Ecosystem, BNB Chain Ecosystem, Ethe...                 []
#
#   country_origin                            contract_address  \
# 0                 0x6982508145454ce325ddbe47a25d4ec3d2311933
#
#    sentiment_votes_up_percentage  sentiment_votes_down_percentage  ...  \
# 0                          76.54                            23.46  ...
#
#                 platforms.binance-smart-chain  \
# 0  0x25d887ce7a35172c62febfd67a1856f20faebb00
#
#                        platforms.arbitrum-one  \
# 0  0x25d887ce7a35172c62febfd67a1856f20faebb00
#
#   detail_platforms.ethereum.decimal_place  \
# 0                                      18
#
#    detail_platforms.ethereum.contract_address  \
# 0  0x6982508145454ce325ddbe47a25d4ec3d2311933
#
#   detail_platforms.binance-smart-chain.decimal_place  \
# ...

# %%
# Ruta del archivo JSON
json_path_usdt = r'Dataset JSON/informacion general/usdt.json'

# Cargar el contenido del archivo JSON
with open(json_path_usdt, 'rb') as file:
    json_data_usdt = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_usdt = json.loads(json_data_usdt)

# Normalizar el JSON y crear un DataFrame
usdt = pd.json_normalize(json_dict_usdt)

# Eliminar columnas nulas o que sean iguales a 0
usdt = usdt.dropna(axis=1, how='all')
usdt = usdt.loc[:, (usdt != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='community')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='market_data.ath')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='description')))]

# Cambiar nombres de columnas
usdt = usdt.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
usdt = usdt.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='market_data')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='localization')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='links')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='image')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='developer_data')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='public_interest')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='ico_data')))]
usdt = usdt[usdt.columns.drop(list(usdt.filter(regex='platforms')))]
usdt
# Out:
#        id symbol    name asset_platform_id  \
# 0  tether   usdt  Tether          ethereum
#
#                                           categories additional_notices  \
# 0  [Mantle Ecosystem, Solana Ecosystem, Canto Eco...                 []
#
#   country_origin                            contract_address  \
# 0                 0xdac17f958d2ee523a2206206994597c13d831ec7
#
#    sentiment_votes_up_percentage  sentiment_votes_down_percentage  \
# 0                             60                               40
#
#    watchlist_portfolio_users  market_cap_rank  coingecko_rank  \
# 0                     283004                3             150
#
#    coingecko_score  liquidity_score status_updates              last_updated  \
# 0           41.416          101.651             []  2023-08-10T20:10:00.399Z
#
#                                              tickers  total_supply  \
# 0  [{'base': 'USDC', 'target': 'USDT', 'market': ...  8.353293e+10
#
#    circulating_supply
# ...

# %%
# Ruta del archivo JSON
json_path_worldcoin = r'Dataset JSON/informacion general/worldcoin.json'

# Cargar el contenido del archivo JSON
with open(json_path_worldcoin, 'rb') as file:
    json_data_worldcoin = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_worldcoin = json.loads(json_data_worldcoin)

# Normalizar el JSON y crear un DataFrame
worldcoin = pd.json_normalize(json_dict_worldcoin)

# Eliminar columnas nulas o que sean iguales a 0
worldcoin = worldcoin.dropna(axis=1, how='all')
worldcoin = worldcoin.loc[:, (worldcoin != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='community')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='market_data.ath')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='description')))]

# Cambiar nombres de columnas
worldcoin = worldcoin.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
worldcoin = worldcoin.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='market_data')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='localization')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='links')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='image')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='developer_data')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='public_interest')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='ico_data')))]
worldcoin = worldcoin[worldcoin.columns.drop(list(worldcoin.filter(regex='platforms')))]
worldcoin
# Out:
#           id symbol       name hashing_algorithm categories  \
# 0  worldcoin    wdc  WorldCoin            Scrypt         []
#
#   additional_notices country_origin genesis_date  watchlist_portfolio_users  \
# 0                 []                  2013-05-14                       3582
#
#    market_cap_rank  coingecko_rank  coingecko_score  developer_score  \
# 0             3608            2686           11.995           26.498
#
#    liquidity_score status_updates              last_updated  \
# 0                1             []  2023-08-10T20:06:50.888Z
#
#                                              tickers  total_supply  \
# 0  [{'base': 'WDC', 'target': 'USDT', 'market': {...     265000000
#
#    circulating_supply
# 0               18450

# %%
# Ruta del archivo JSON
json_path_xrp = r'Dataset JSON/informacion general/xrp.json'

# Cargar el contenido del archivo JSON
with open(json_path_xrp, 'rb') as file:
    json_data_xrp = file.read().decode('utf-8')

# Convertir la cadena JSON en un diccionario
json_dict_xrp = json.loads(json_data_xrp)

# Normalizar el JSON y crear un DataFrame
xrp = pd.json_normalize(json_dict_xrp)

# Eliminar columnas nulas o que sean iguales a 0
xrp = xrp.dropna(axis=1, how='all')
xrp = xrp.loc[:, (xrp != 0).any(axis=0)]

# Eliminar columnas que contienen ciertas palabras clave
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='community')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='market_data.ath')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='description')))]

# Cambiar nombres de columnas
xrp = xrp.rename(columns={'market_data.circulating_supply': 'circulating_supply'})
xrp = xrp.rename(columns={'market_data.total_supply': 'total_supply'})

# Eliminar columnas no deseadas
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='market_data')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='localization')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='links')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='image')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='developer_data')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='public_interest')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='ico_data')))]
xrp = xrp[xrp.columns.drop(list(xrp.filter(regex='platforms')))]
xrp
# Out:
#        id symbol name        categories additional_notices country_origin  \
# 0  ripple    xrp  XRP  [Cryptocurrency]                 []
#
#    sentiment_votes_up_percentage  sentiment_votes_down_percentage  \
# 0                          77.56                            22.44
#
#    watchlist_portfolio_users  market_cap_rank  coingecko_rank  \
# 0                     566466                5               3
#
#    coingecko_score  developer_score  liquidity_score status_updates  \
# 0           66.223           83.005            81.07             []
#
#                last_updated  \
# 0  2023-08-10T20:12:06.736Z
#
#                                              tickers  total_supply  \
# 0  [{'base': 'XRP', 'target': 'USDT', 'market': {...   99988519823
#
#    circulating_supply
# 0         52787284454

# %%
#Ahora uniremos todos los dataframe por interseccion entre sus columnas
#Para ello usaremos la funcion merge de pandas

# Lista de los DataFrames que has creado
dataframes = [arkham, bnb, usdt, bitcoin, dogecoin, ethereum, matic, pepe, worldcoin, xrp]

# Concatenar los DataFrames
combined_crip = pd.concat(dataframes, ignore_index=True)
combined_crip = combined_crip[combined_crip.columns.drop(list(combined_crip.filter(regex='platform')))]

#volvemos a eliminar las columnas donde haya listas vacias o nulas
combined_crip = combined_crip.drop


#Convertimos combined_crip en un dataframe de pandas
combined_crip = pd.DataFrame(combined_crip)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_63729/1148588351.py in ?()
#      12 combined_crip = combined_crip.drop
#      13
#      14
#      15 #Convertimos combined_crip en un dataframe de pandas
# ---> 16 combined_crip = pd.DataFrame(combined_crip)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     813                 )
#     814         # For data is scalar
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#     820             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
#Cambiaremos los valores de "country_origin" donde sean nulos por "unknown"
combined_crip['country_origin'] = combined_crip['country_origin'].replace('', 'Unknown')
combined_crip['country_origin']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 #Cambiaremos los valores de "country_origin" donde sean nulos por "unknown"
# ----> 2 combined_crip['country_origin'] = combined_crip['country_origin'].replace('', 'Unknown')
#       3 combined_crip['country_origin']
#
# TypeError: 'method' object is not subscriptable

# %%
#lo pasamos a un archivo csv
combined_crip.to_csv('Informacion General.csv', index=False)

# %%
#Ahora leeremos las capitalizaciones y cotizaciones de las criptomonedas a lo largo del tiempo, para ello usaremos la API de CoinGecko tambien.
arkham_cap_json = r'Dataset JSON/capitalizacion y cotizacion/arkham.json'
bitcoin_cap_json = r'Dataset JSON/capitalizacion y cotizacion/bitcoin.json'
ethereum_cap_json = r'Dataset JSON/capitalizacion y cotizacion/ethereum.json'
dogecoin_cap_json = r'Dataset JSON/capitalizacion y cotizacion/dogecoin.json'
usdt_cap_json = r'Dataset JSON/capitalizacion y cotizacion/usdt.json'
xrp_cap_json = r'Dataset JSON/capitalizacion y cotizacion/xrp.json'
matic_cap_json = r'Dataset JSON/capitalizacion y cotizacion/matic.json'
worldcoin_cap_json = r'Dataset JSON/capitalizacion y cotizacion/worldcoin.json'
pepe_cap_json = r'Dataset JSON/capitalizacion y cotizacion/pepe.json'
bnb_cap_json = r'Dataset JSON/capitalizacion y cotizacion/bnb.json'

# %%
# Load the content of the JSON file
with open(arkham_cap_json, 'r') as file:
    arkham_cap_content = file.read()

# Convert the JSON string into a dictionary
arkham_cap = json.loads(arkham_cap_content)

# Normalize the JSON and create a DataFrame
arkham = pd.json_normalize(arkham_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = arkham_cap['prices']
prices_df_arkham = pd.DataFrame(prices_data, columns=['arkham market_cap', 'Arkham price'])
#Haremos una columna dia numero para poder hacer un plot de la evolucion de los precios y esta sera en funcion del indice de fila
prices_df_arkham['dia'] = prices_df_arkham.index
#Dejamos las ultimas 30 filas para estudiar su comportamiento en el ultimo mes
prices_df_arkham30 = prices_df_arkham.tail(30)
#Reseteamos el indice
prices_df_arkham30 = prices_df_arkham30.reset_index(drop=True)
#convertimos el indice en la columna dia
prices_df_arkham30['dia'] = prices_df_arkham30.index + 1
prices_df_arkham30
# Out:
#     arkham market_cap  Arkham price  dia
# 0       1690070400000      0.622242    1
# 1       1690156800000      0.597445    2
# 2       1690243200000      0.530439    3
# 3       1690329600000      0.512679    4
# 4       1690416000000      0.543409    5
# 5       1690502400000      0.557870    6
# 6       1690588800000      0.541070    7
# 7       1690675200000      0.520037    8
# 8       1690761600000      0.505134    9
# 9       1690848000000      0.508447   10
# 10      1690934400000      0.506081   11
# 11      1691020800000      0.470809   12
# 12      1691107200000      0.459826   13
# 13      1691193600000      0.455571   14
# 14      1691280000000      0.423871   15
# 15      1691366400000      0.442911   16
# 16      1691452800000      0.421356   17
# 17      1691539200000      0.421502   18
# 18      1691625600000      0.424579   19
# 19      1691712000000      0.412053   20
# 20      1691798400000      0.419833   21
# 21      1691884800000      0.435984   22
# ...

# %%
with open(bitcoin_cap_json, 'r') as file:
    bitcoin_cap_content = file.read()

# Convertir el JSON en un diccionario
bitcoin_cap = json.loads(bitcoin_cap_content)

# Normalize the JSON and create a DataFrame
bitcoin = pd.json_normalize(bitcoin_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = bitcoin_cap['prices']
prices_df_bitcoin = pd.DataFrame(prices_data, columns=['bitcoin market_cap', 'bitcoin price'])
#Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_bitcoin['dia'] = prices_df_bitcoin.index
#Eliminamos las 30 ultimas filas 
prices_df_bitcoin30 = prices_df_bitcoin.tail(30)
#Reseteamos el indice
prices_df_bitcoin30 = prices_df_bitcoin30.reset_index(drop=True)
prices_df_bitcoin30['dia'] = prices_df_bitcoin30.index + 1
prices_df_bitcoin30
# Out:
#     bitcoin market_cap  bitcoin price  dia
# 0        1689292800000   31446.014971    1
# 1        1689379200000   30311.827808    2
# 2        1689465600000   30297.971400    3
# 3        1689552000000   30237.334785    4
# 4        1689638400000   30147.860079    5
# 5        1689724800000   29848.032273    6
# 6        1689811200000   29919.874838    7
# 7        1689897600000   29787.041530    8
# 8        1689984000000   29914.682728    9
# 9        1690070400000   29710.155936   10
# 10       1690156800000   30057.956719   11
# 11       1690243200000   29184.901913   12
# 12       1690329600000   29222.974630   13
# 13       1690416000000   29363.672908   14
# 14       1690502400000   29200.244001   15
# 15       1690588800000   29314.097387   16
# 16       1690675200000   29356.747746   17
# 17       1690761600000   29277.755810   18
# 18       1690848000000   29233.136366   19
# 19       1690934400000   29537.109747   20
# 20       1691020800000   29146.636271   21
# ...

# %%
with open(bnb_cap_json, 'r') as file:
    bnb_cap_content = file.read()

# Convertir el JSON en un diccionario
bnb_cap = json.loads(bnb_cap_content)

# Normalize the JSON and create a DataFrame
bnb = pd.json_normalize(bnb_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = bnb_cap['prices']
prices_df_bnb = pd.DataFrame(prices_data, columns=['bnb market_cap', 'bnb price'])
#Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_bnb['dia'] = prices_df_bnb.index
#Dejamos las ultimas 30 filas
prices_df_bnb30 = prices_df_bnb.tail(30)
#Reseteamos el indice 
prices_df_bnb30 = prices_df_bnb30.reset_index(drop=True)
prices_df_bnb30['dia'] = prices_df_bnb30.index + 1
prices_df_bnb30
# Out:
#     bnb market_cap   bnb price  dia
# 0    1689292800000  255.788291    1
# 1    1689379200000  247.695854    2
# 2    1689465600000  251.092986    3
# 3    1689552000000  242.749491    4
# 4    1689638400000  244.197168    5
# 5    1689724800000  240.270930    6
# 6    1689811200000  241.332773    7
# 7    1689897600000  242.624777    8
# 8    1689984000000  243.768842    9
# 9    1690070400000  240.537852   10
# 10   1690156800000  242.381424   11
# 11   1690243200000  238.965494   12
# 12   1690329600000  237.730347   13
# 13   1690416000000  239.020092   14
# 14   1690502400000  240.417367   15
# 15   1690588800000  241.857825   16
# 16   1690675200000  242.556325   17
# 17   1690761600000  242.540332   18
# 18   1690848000000  241.193557   19
# 19   1690934400000  247.428737   20
# 20   1691020800000  240.379008   21
# 21   1691107200000  241.143787   22
# 22   1691193600000  241.492208   23
# 23   1691280000000  242.881970   24
# 24   1691366400000  242.574998   25
# ...

# %%
with open(dogecoin_cap_json, 'r') as file:
    dogecoin_cap_content = file.read()

# Convertir el JSON en un diccionario
dogecoin_cap = json.loads(dogecoin_cap_content)

# Normalize the JSON and create a DataFrame
dogecoin = pd.json_normalize(dogecoin_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = dogecoin_cap['prices']
prices_df_dogecoin = pd.DataFrame(prices_data, columns=['dogecoin market_cap', 'dogecoin price'])
#Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_dogecoin['dia'] = prices_df_dogecoin.index
#Dejamos los ultimos 30 días con el obetivo de monitorear el ultimo mes
prices_df_dogecoin30 = prices_df_dogecoin.tail(30)
#Reseteamos el indice y lo aplicamos sobre la columna dia
prices_df_dogecoin30.reset_index(inplace=True)
prices_df_dogecoin30['dia'] = prices_df_dogecoin30.index + 1
prices_df_dogecoin30
# Out:
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_63729/3077975503.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_df_dogecoin30['dia'] = prices_df_dogecoin30.index + 1
#     index  dogecoin market_cap  dogecoin price  dia
# 0    3495        1689292800000        0.070533    1
# 1    3496        1689379200000        0.068471    2
# 2    3497        1689465600000        0.072033    3
# 3    3498        1689552000000        0.069662    4
# 4    3499        1689638400000        0.069974    5
# 5    3500        1689724800000        0.068610    6
# 6    3501        1689811200000        0.070176    7
# 7    3502        1689897600000        0.070596    8
# 8    3503        1689984000000        0.073368    9
# ...

# %%
with open(ethereum_cap_json, 'r') as file:
    ethereum_cap_content = file.read()

# Convertir el JSON en un diccionario
ethereum_cap = json.loads(ethereum_cap_content)

# Normalize the JSON and create a DataFrame
ethereum = pd.json_normalize(ethereum_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = ethereum_cap['prices']
prices_df_ethereum = pd.DataFrame(prices_data, columns=['ethereum market_cap', 'ethereum price'])
#Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_ethereum['dia'] = prices_df_ethereum.index
#Dejamos las ultimas 30 filas
prices_df_ethereum30 = prices_df_ethereum.tail(30)
#Reseteamos los indices para que empiecen en 0
prices_df_ethereum30 = prices_df_ethereum30.reset_index(drop=True)
#y lo aplicamos a la columna dia 
prices_df_ethereum30['dia'] = prices_df_ethereum30.index + 1
prices_df_ethereum30
# Out:
#     ethereum market_cap  ethereum price  dia
# 0         1689292800000     2003.253616    1
# 1         1689379200000     1935.940241    2
# 2         1689465600000     1931.389384    3
# 3         1689552000000     1923.035990    4
# 4         1689638400000     1912.122836    5
# 5         1689724800000     1897.199113    6
# 6         1689811200000     1889.223806    7
# 7         1689897600000     1891.014505    8
# 8         1689984000000     1891.472403    9
# 9         1690070400000     1858.311196   10
# 10        1690156800000     1887.826981   11
# 11        1690243200000     1850.431151   12
# 12        1690329600000     1857.596593   13
# 13        1690416000000     1871.533106   14
# 14        1690502400000     1858.777021   15
# 15        1690588800000     1874.693995   16
# 16        1690675200000     1880.918077   17
# 17        1690761600000     1861.869910   18
# 18        1690848000000     1857.276196   19
# 19        1690934400000     1869.745109   20
# ...

# %%
with open(matic_cap_json, 'r') as file:
    matic_cap_content = file.read()

# Convertir el JSON en un diccionario
matic_cap = json.loads(matic_cap_content)

# Normalize the JSON and create a DataFrame
matic = pd.json_normalize(matic_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = matic_cap['prices']
prices_df_matic = pd.DataFrame(prices_data, columns=['matic market_cap', 'matic price'])
#Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_matic['dia'] = prices_df_matic.index
#Dejamos las ultimas 30 filas
prices_df_matic30 = prices_df_matic.tail(30)
#Reseteamos los índices
prices_df_matic30 = prices_df_matic30.reset_index(drop=True)
prices_df_matic30['dia'] = prices_df_matic30.index + 1
prices_df_matic30
# Out:
#     matic market_cap  matic price  dia
# 0      1689292800000     0.848912    1
# 1      1689379200000     0.808997    2
# 2      1689465600000     0.799175    3
# 3      1689552000000     0.768094    4
# 4      1689638400000     0.778668    5
# 5      1689724800000     0.737500    6
# 6      1689811200000     0.744695    7
# 7      1689897600000     0.766161    8
# 8      1689984000000     0.770982    9
# 9      1690070400000     0.743669   10
# 10     1690156800000     0.757537   11
# 11     1690243200000     0.728412   12
# 12     1690329600000     0.708470   13
# 13     1690416000000     0.722021   14
# 14     1690502400000     0.716060   15
# 15     1690588800000     0.709453   16
# 16     1690675200000     0.718811   17
# 17     1690761600000     0.697725   18
# 18     1690848000000     0.688207   19
# 19     1690934400000     0.698898   20
# 20     1691020800000     0.680097   21
# 21     1691107200000     0.668413   22
# 22     1691193600000     0.664277   23
# ...

# %%
with open(pepe_cap_json, 'r') as file:
    pepe_cap_content = file.read()

# Convertir el JSON en un diccionario
pepe_cap = json.loads(pepe_cap_content)

# Normalize the JSON and create a DataFrame
pepe = pd.json_normalize(pepe_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = pepe_cap['prices']
prices_df_pepe = pd.DataFrame(prices_data, columns=['pepe market_cap', 'pepe price'])
# Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_pepe['dia'] = prices_df_pepe.index
#Nos quedamos con los ultimos 30 dias
prices_df_pepe30 = prices_df_pepe.tail(30)
#reseteamos el indice a 0 
prices_df_pepe30 = prices_df_pepe30.reset_index(drop=True)
prices_df_pepe30['dia'] = prices_df_pepe30.index + 1
prices_df_pepe30
# Out:
#     pepe market_cap  pepe price  dia
# 0     1689292800000    0.000002    1
# 1     1689379200000    0.000002    2
# 2     1689465600000    0.000002    3
# 3     1689552000000    0.000002    4
# 4     1689638400000    0.000002    5
# 5     1689724800000    0.000002    6
# 6     1689811200000    0.000002    7
# 7     1689897600000    0.000002    8
# 8     1689984000000    0.000002    9
# 9     1690070400000    0.000001   10
# 10    1690156800000    0.000002   11
# 11    1690243200000    0.000001   12
# 12    1690329600000    0.000001   13
# 13    1690416000000    0.000001   14
# 14    1690502400000    0.000001   15
# 15    1690588800000    0.000001   16
# 16    1690675200000    0.000001   17
# 17    1690761600000    0.000001   18
# 18    1690848000000    0.000001   19
# 19    1690934400000    0.000001   20
# 20    1691020800000    0.000001   21
# 21    1691107200000    0.000001   22
# 22    1691193600000    0.000001   23
# 23    1691280000000    0.000001   24
# ...

# %%
with open(usdt_cap_json, 'r') as file:
    usdt_cap_content = file.read()

# Convertir el JSON en un diccionario
usdt_cap = json.loads(usdt_cap_content)

# Normalize the JSON and create a DataFrame
usdt = pd.json_normalize(usdt_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = usdt_cap['prices']
prices_df_usdt = pd.DataFrame(prices_data, columns=['usdt market_cap', 'usdt price'])
# Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_usdt['dia'] = prices_df_usdt.index
#Nos quedamos con los últimos 30 días
prices_df_usdt30 = prices_df_usdt.tail(30)
#hacemos un index reset para que el index sea el número de fila
prices_df_usdt30.reset_index(drop=True, inplace=True)
prices_df_usdt30['dia'] = prices_df_usdt30.index + 1
prices_df_usdt30
# Out:
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_63729/3598865899.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_df_usdt30['dia'] = prices_df_usdt30.index + 1
#     usdt market_cap  usdt price  dia
# 0     1689292800000    1.000392    1
# 1     1689379200000    1.000707    2
# 2     1689465600000    1.000653    3
# 3     1689552000000    1.000548    4
# 4     1689638400000    0.999807    5
# 5     1689724800000    1.000481    6
# 6     1689811200000    1.000293    7
# 7     1689897600000    1.000199    8
# 8     1689984000000    1.000050    9
# 9     1690070400000    0.999749   10
# 10    1690156800000    0.999898   11
# 11    1690243200000    1.000097   12
# 12    1690329600000    0.999606   13
# ...

# %%
with open(worldcoin_cap_json, 'r') as file:
    worldcoin_cap_content = file.read()

# Convertir el JSON en un diccionario
worldcoin_cap = json.loads(worldcoin_cap_content)

# Normalize the JSON and create a DataFrame
worldcoin = pd.json_normalize(worldcoin_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = worldcoin_cap['prices']
prices_df_worldcoin = pd.DataFrame(prices_data, columns=['worldcoin market_cap', 'worldcoin price'])
# Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_worldcoin['dia'] = prices_df_worldcoin.index
#Nos quedaremos con los ultimos 30 dias
prices_df_worldcoin30 = prices_df_worldcoin.tail(30)
#Los reindexamos para que el plot empiece en 1
prices_df_worldcoin30 = prices_df_worldcoin30.reset_index(drop=True)
prices_df_worldcoin30['dia'] = prices_df_worldcoin30.index + 1

prices_df_worldcoin30
# Out:
#     worldcoin market_cap  worldcoin price  dia
# 0          1691845257599         1.787810    1
# 1          1691848865353         1.769639    2
# 2          1691852492569         1.771126    3
# 3          1691856059202         1.774080    4
# 4          1691859668535         1.769262    5
# 5          1691863276273         1.771651    6
# 6          1691866855572         1.749482    7
# 7          1691870459764         1.758132    8
# 8          1691874063830         1.749574    9
# 9          1691877655575         1.752980   10
# 10         1691881251383         1.762024   11
# 11         1691884851761         1.757411   12
# 12         1691888415952         1.771873   13
# 13         1691892008506         1.788858   14
# 14         1691895603904         1.800615   15
# 15         1691899246400         1.797507   16
# 16         1691902814891         1.803319   17
# 17         1691906416094         1.804206   18
# 18         1691910004119         1.811840   19
# ...

# %%
with open(xrp_cap_json, 'r') as file:
    xrp_cap_content = file.read()

# Convertir el JSON en un diccionario
xrp_cap = json.loads(xrp_cap_content)

# Normalize the JSON and create a DataFrame
xrp = pd.json_normalize(xrp_cap)

# Convertir las listas anidadas en filas individuales para la columna 'prices'
prices_data = xrp_cap['prices']
prices_df_xrp = pd.DataFrame(prices_data, columns=['xrp market_cap', 'xrp price'])
# Haremos una columna día número para poder hacer un plot de la evolución de los precios y esta será en función del índice de fila
prices_df_xrp['dia'] = prices_df_xrp.index
#Dejasmos unicamente los 30 ultimos dias 
prices_df_xrp30 = prices_df_xrp.tail(30)
# y los re indexamos en la columna dia
prices_df_xrp30 = prices_df_xrp30.reset_index(drop=True)
prices_df_xrp30['dia'] = prices_df_xrp30.index=range(1,31)

prices_df_xrp30
# Out:
#     xrp market_cap  xrp price  dia
# 1    1689292800000   0.812509    1
# 2    1689379200000   0.719679    2
# 3    1689465600000   0.713256    3
# 4    1689552000000   0.747667    4
# 5    1689638400000   0.739496    5
# 6    1689724800000   0.781263    6
# 7    1689811200000   0.821237    7
# 8    1689897600000   0.793284    8
# 9    1689984000000   0.772681    9
# 10   1690070400000   0.731402   10
# 11   1690156800000   0.737991   11
# 12   1690243200000   0.703525   12
# 13   1690329600000   0.710253   13
# 14   1690416000000   0.715877   14
# 15   1690502400000   0.713436   15
# 16   1690588800000   0.712297   16
# 17   1690675200000   0.712607   17
# 18   1690761600000   0.704911   18
# 19   1690848000000   0.699030   19
# 20   1690934400000   0.707216   20
# 21   1691020800000   0.684740   21
# 22   1691107200000   0.664210   22
# 23   1691193600000   0.635810   23
# 24   1691280000000   0.628430   24
# 25   1691366400000   0.622153   25
# 26   1691452800000   0.620838   26
# ...

# %%
#guardamos cada uno en un archivo csv en una carpeta llamada data
prices_df_arkham.to_csv('data/prices_df_arkham.csv', index=False)
prices_df_bitcoin.to_csv('data/prices_df_bitcoin.csv', index=False)
prices_df_bnb.to_csv('data/prices_df_bnb.csv', index=False)
prices_df_ethereum.to_csv('data/prices_df_ethereum.csv', index=False)
prices_df_dogecoin.to_csv('data/prices_df_dogecoin.csv', index=False)
prices_df_matic.to_csv('data/prices_df_matic.csv', index=False)
prices_df_pepe.to_csv('data/prices_df_pepe.csv', index=False)
prices_df_usdt.to_csv('data/prices_df_usdt.csv', index=False)
prices_df_worldcoin.to_csv('data/prices_df_worldcoin.csv', index=False)
prices_df_xrp.to_csv('data/prices_df_xrp.csv', index=False)

# %%
capitalizaciones_json = r'Dataset JSON/capitalizaciones.json'
with open(capitalizaciones_json, 'r') as file:
    capitalizaciones_content = file.read()

# Convertir el JSON en un diccionario
capitalizaciones = json.loads(capitalizaciones_content)

# Normalize the JSON and create a DataFrame
capitalizaciones_df = pd.json_normalize(capitalizaciones)
capitalizaciones_df.head()
# Out:
#    data.active_cryptocurrencies  data.upcoming_icos  data.ongoing_icos  \
# 0                         10029                   0                 49
#
#    data.ended_icos  data.markets  data.total_market_cap.btc  \
# 0             3376           800               4.140579e+07
#
#    data.total_market_cap.eth  data.total_market_cap.ltc  \
# 0               6.609427e+08               1.456081e+10
#
#    data.total_market_cap.bch  data.total_market_cap.bnb  ...  \
# 0               5.131096e+09               5.034899e+09  ...
#
#    data.market_cap_percentage.usdt  data.market_cap_percentage.bnb  \
# 0                         6.819699                        3.054559
#
#    data.market_cap_percentage.xrp  data.market_cap_percentage.usdc  \
# 0                        2.745171                         2.147863
#
#    data.market_cap_percentage.steth  data.market_cap_percentage.doge  \
# 0                          1.212929                         0.869776
#
# ...

# %%
#Vamos a unir todos los dataframe por la columna dia 
#critpos = pd.merge(prices_df_arkham, prices_df_bitcoin, prices_df_bnb, prices_df_dogecoin, prices_df_ethereum, prices_df_matic, prices_df_pepe, prices_df_usdt, prices_df_worldcoin, prices_df_xrp)
mesCrypto = (prices_df_arkham30.merge(prices_df_bitcoin30, on='dia', how='left')
          .merge(prices_df_bnb30, on='dia', how='left')
          .merge(prices_df_dogecoin30, on='dia', how='left')
          .merge(prices_df_ethereum30, on='dia', how='left')
          .merge(prices_df_matic30, on='dia', how='left')
          .merge(prices_df_pepe30, on='dia', how='left')
          .merge(prices_df_usdt30, on='dia', how='left')
          .merge(prices_df_worldcoin30, on='dia', how='left')
          .merge(prices_df_xrp30, on='dia', how='left'))
mesCrypto
# Out:
#     arkham market_cap  Arkham price  dia  bitcoin market_cap  bitcoin price  \
# 0       1690070400000      0.622242    1       1689292800000   31446.014971
# 1       1690156800000      0.597445    2       1689379200000   30311.827808
# 2       1690243200000      0.530439    3       1689465600000   30297.971400
# 3       1690329600000      0.512679    4       1689552000000   30237.334785
# 4       1690416000000      0.543409    5       1689638400000   30147.860079
# 5       1690502400000      0.557870    6       1689724800000   29848.032273
# 6       1690588800000      0.541070    7       1689811200000   29919.874838
# 7       1690675200000      0.520037    8       1689897600000   29787.041530
# 8       1690761600000      0.505134    9       1689984000000   29914.682728
# 9       1690848000000      0.508447   10       1690070400000   29710.155936
# 10      1690934400000      0.506081   11       1690156800000   30057.956719
# ...

# %%
capitalizaciones_df.to_csv('data/capitalizaciones.csv', index=False)

# %%
exchanges_json = r'Dataset JSON/Exchanges.json'
with open(exchanges_json, 'r') as file:
    exchanges_content = file.read()

# Convertir el JSON en un diccionario
exchanges = json.loads(exchanges_content)

# Normalize the JSON and create a DataFrame
exchanges_df = pd.json_normalize(exchanges)
exchanges_df
# Out:
#                             id                          name  \
# 0                      binance                       Binance
# 1                         gdax             Coinbase Exchange
# 2                   bybit_spot                         Bybit
# 3                        huobi                         Huobi
# 4                       kraken                        Kraken
# ..                         ...                           ...
# 95                     bitazza                       Bitazza
# 96                     osmosis                       Osmosis
# 97                      pulsex                        PulseX
# 98                   gmo_japan                     GMO Japan
# 99  kyberswap_elastic_arbitrum  Kyberswap Elastic (Arbitrum)
#
#     year_established                 country  \
# 0             2017.0          Cayman Islands
# 1             2012.0           United States
# 2             2018.0  British Virgin Islands
# 3             2013.0              Seychelles
# ...

# %%
exchanges_df.to_csv('data/exchanges.csv', index=False)
